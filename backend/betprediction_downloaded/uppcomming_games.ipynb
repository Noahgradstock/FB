# %%
import pandas as pd
import numpy as np
pd.set_option("display.max_columns", None)
pd.set_option("display.width", None)

# %%
df_next_games = pd.read_csv('https://www.football-data.co.uk/fixtures.csv')

df_next_games['Date'] = pd.to_datetime(df_next_games['Date'], format='%d/%m/%Y')
df_next_games= df_next_games.sort_values(by='Date')
df_next_games = df_next_games[::-1]

df_next_games.reset_index(inplace=True)

# %%
season_list = ['1617', '1718', '1819', '1920', '2021', '2122', '2223', '2324', '2425']
league_list = ['E0', 'E1', 'E2', 'E3', 'SC0', 'SC1', 'SC2', 'D1', 'D2', 'I1', 'I2', 'SP1', 'SP2', 'F1', 'F2', 'N1', 'B1', 'P1', 'T1', 'G1'] 

for league in league_list:
    if league in df_next_games['Div'].unique():
        globals()[f"df_{league}"] = df_next_games[df_next_games['Div'] == league].reset_index(drop=True)

df_D2
# Out:
#    index Div       Date   Time            HomeTeam      AwayTeam Referee  \
# 0     24  D2 2025-04-27  12:30            Hannover       FC Koln     NaN
# 1     25  D2 2025-04-27  12:30      Kaiserslautern    Schalke 04     NaN
# 2     23  D2 2025-04-27  12:30             Hamburg     Karlsruhe     NaN
# 3     21  D2 2025-04-26  12:00          Regensburg  Braunschweig     NaN
# 4     22  D2 2025-04-26  19:30  Fortuna Dusseldorf      Nurnberg     NaN
# 5     20  D2 2025-04-26  12:00     Preußen Münster     Darmstadt     NaN
# 6     19  D2 2025-04-26  12:00           Paderborn    Elversberg     NaN
# 7     18  D2 2025-04-25  17:30              Hertha     Magdeburg     NaN
# 8     17  D2 2025-04-25  17:30      Greuther Furth           Ulm     NaN
#
#    B365H  B365D  B365A  BWH  BWD  BWA   BFH   BFD   BFA   PSH   PSD   PSA  \
# 0   3.30   3.40   2.15  NaN  NaN  NaN  3.10  3.50  2.15  3.32  3.48  2.17
# 1   2.10   3.50   3.25  NaN  NaN  NaN  2.10  3.60  3.10  2.12  3.62  3.32
# ...
